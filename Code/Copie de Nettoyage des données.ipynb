# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#import des données
DF_first=pd.read_table('/content/drive/MyDrive/Michelin/Sujet 1/Code/FirstTrip.csv',sep=";",header=0)
DF_first.head()
DF_second=pd.read_table('/content/drive/MyDrive/Michelin/Sujet 1/Code/SecondTrip.csv',sep=";",header=0)
DF_second.head()
# Out:
#             DateTime Imbibition    Vehicle TireBrand TireName TireSizeFront  \
# 0  19.05.02 09:54:12       Nimb  Panamera1        MI      PSS     255_40_20
# 1  19.05.02 09:54:12       Nimb  Panamera1        MI      PSS     255_40_20
# 2  19.05.02 09:54:12       Nimb  Panamera1        MI      PSS     255_40_20
# 3  19.05.02 09:54:12       Nimb  Panamera1        MI      PSS     255_40_20
# 4  19.05.02 09:54:12       Nimb  Panamera1        MI      PSS     255_40_20
#
#   TireSizeRear TirePressure Load        Track  ...     mfcc4    mfcc5  \
# 0    295_35_20          23b   2p  TrackOthers  ...  0.234040  0.22499
# 1    295_35_20          23b   2p  TrackOthers  ... -0.002959  0.27452
# 2    295_35_20          23b   2p  TrackOthers  ... -0.003795  0.24507
# 3    295_35_20          23b   2p  TrackOthers  ...  0.222660  0.18201
# 4    295_35_20          23b   2p  TrackOthers  ... -0.046865  0.18653
#
#      mfcc6    mfcc7    mfcc8     mfcc9    mfcc10    mfcc11    mfcc12    mfcc13
# ...

# %% [markdown]
# # Nouvelle section

# %%
print(DF_first.shape)
#Les colonnes hors jeu de données de son
print(DF_first.columns[:22])

print(DF_second.shape)
#Les colonnes hors jeu de données de son
print(DF_second.columns[:22])
# Out:
# (20513, 146)
# Index(['DateTime', 'Imbibition', 'Vehicle', 'TireBrand', 'TireName',
#        'TireSizeFront', 'TireSizeRear', 'TirePressure', 'Load', 'Track',
#        'FrontRear', 'channel', 'latitudeT', 'longitudeT', 'speed', 'accelX',
#        'accelY', 'speedClass', 'ambiantTemperature', 'weatherCheck',
#        'textureCheck', 'TireWear'],
#       dtype='object')
# (19807, 146)
# Index(['DateTime', 'Imbibition', 'Vehicle', 'TireBrand', 'TireName',
#        'TireSizeFront', 'TireSizeRear', 'TirePressure', 'Load', 'Track',
#        'FrontRear', 'channel', 'latitudeT', 'longitudeT', 'speed', 'accelX',
#        'accelY', 'speedClass', 'ambiantTemperature', 'weatherCheck',
#        'textureCheck', 'TireWear'],
#       dtype='object')

# %%
#Valeurs a prédire à la fin du DataFrame/content/drive/MyDrive/Michelin/Sujet 1/
Y=['weatherCheck','textureCheck', 'TireWear']
Y1 = DF_first.pop('weatherCheck')
Y2 = DF_first.pop('textureCheck')
Y3 = DF_first.pop('TireWear')
DF_first.insert(DF_first.shape[1], 'weatherCheck', Y1)
DF_first.insert(DF_first.shape[1], 'textureCheck', Y2)
DF_first.insert(DF_first.shape[1], 'TireWear', Y3)
print(DF_first.columns[-3:])

#Valeurs a prédire à la fin du DataFrame
Y=['weatherCheck','textureCheck', 'TireWear']
Y1 = DF_second.pop('weatherCheck')
Y2 = DF_second.pop('textureCheck')
Y3 = DF_second.pop('TireWear')
DF_second.insert(DF_second.shape[1], 'weatherCheck', Y1)
DF_second.insert(DF_second.shape[1], 'textureCheck', Y2)
DF_second.insert(DF_second.shape[1], 'TireWear', Y3)
print(DF_second.columns[-3:])
# Out:
# Index(['weatherCheck', 'textureCheck', 'TireWear'], dtype='object')
# Index(['weatherCheck', 'textureCheck', 'TireWear'], dtype='object')
# /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:3249: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   if (await self.run_code(code, result,  async_=asy)):

# %%
print(DF_first.shape)

print(DF_second.shape)
# Out:
# (20513, 146)
# (19807, 146)

# %%
#Supression des colonnes inutilesDF_second
supr=['Vehicle','TireBrand','TireName','TireSizeFront','TireSizeRear','TirePressure','Track','latitudeT','longitudeT', 'DateTime']
#DataTime juste sur deux mois, aucun infos avec le mois etc juste a titre indicatif acquisition
#Vehicle toujours le meme
#TireBrand toujours le meme
#TireName toujours le meme
#TireSizeFront toujours le meme
#TireSizeRear toujours le meme
#TirePressure toujours le meme
#Track le new jeu de données n'aura pas la même piste
#latitudeT coordonnées GPS inutile
#longitudeT coordonnées GPS inutile

DF_first = DF_first.drop(supr,axis=1)
DF_second = DF_second.drop(supr,axis=1)

# %%
print(DF_first.shape)

print(DF_second.shape)
# Out:
# (20513, 136)
# (19807, 136)

# %%
#Convertir le DataFrame en excel
DF_first.to_excel('/content/drive/MyDrive/Michelin/Sujet 1/Code/First.xlsx')

DF_second.to_excel('/content/drive/MyDrive/Michelin/Sujet 1/Code/Second.xlsx')
