# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#import des données
DF=pd.read_excel('/content/drive/MyDrive/Michelin/Sujet 1/Code/clean_data.xlsx',header=0,index_col=0)
DF.head()
# Out:
#   Imbibition Load FrontRear  channel   speed  accelX  accelY  speedClass  \
# 0       Uimb   2p     front        1  108.37  0.1962 -0.2943         110
# 1       Uimb   2p     front        1  108.50  0.0000  0.1962         110
# 2       Uimb   2p     front        1  108.31 -0.2943  0.3924         110
# 3       Uimb   2p     front        1  107.87 -0.0981  0.0981         110
# 4       Uimb   2p     front        1  107.62 -0.0981  0.2943         110
#
#    ambiantTemperature   band1  ...    mfcc7     mfcc8     mfcc9    mfcc10  \
# 0             24.1875 -39.030  ...  0.36199  0.112760 -0.135410 -0.151190
# 1             24.1875 -27.212  ...  0.11064  0.017184 -0.014654 -0.072046
# 2             24.1835 -27.345  ...  0.24850 -0.061575  0.001298 -0.050133
# 3             24.1835 -28.047  ...  0.22439 -0.000048 -0.087832 -0.056982
# 4             24.1796 -27.333  ...  0.18047 -0.031491  0.030885 -0.073779
#
#      mfcc11    mfcc12    mfcc13  weatherCheck  textureCheck       TireWear
# 0  0.138340  0.068698  0.035733       DampWet        Medium  TavNew_TarNew
# 1 -0.047253  0.049386 -0.029621       DampWet        Medium  TavNew_TarNew
# 2  0.013015  0.098812  0.052348       DampWet        Medium  TavNew_TarNew
# 3 -0.044223  0.017767  0.020791       DampWet        Medium  TavNew_TarNew
# 4 -0.038306  0.006146  0.084808       DampWet        Medium  TavNew_TarNew
#
# [5 rows x 136 columns]

# %%
#Types des colonnes
DF.dtypes
# Out:
# Imbibition       object
# Load             object
# FrontRear        object
# channel           int64
# speed           float64
#                  ...
# mfcc12          float64
# mfcc13          float64
# weatherCheck     object
# textureCheck     object
# TireWear         object
# Length: 136, dtype: object

# %%
plt.plot(1,2)
plt.show()

# %%
print(DF.shape)
#Les colonnes hors jeu de données de son
print(DF.columns[:9])
# Out:
# (58032, 136)
# Index(['Imbibition', 'Load', 'FrontRear', 'channel', 'speed', 'accelX',
#        'accelY', 'speedClass', 'ambiantTemperature'],
#       dtype='object')

# %%
liste = ['Imbibition', 'Load', 'FrontRear', 'channel','speed', 'accelX', 'accelY', 'speedClass', 'ambiantTemperature']
df = DF.loc[:,liste]
print(df)
# Out:
#       Imbibition Load FrontRear  channel   speed  accelX  accelY  speedClass  \
# 0           Uimb   2p     front        1  108.37  0.1962 -0.2943         110
# 1           Uimb   2p     front        1  108.50  0.0000  0.1962         110
# 2           Uimb   2p     front        1  108.31 -0.2943  0.3924         110
# 3           Uimb   2p     front        1  107.87 -0.0981  0.0981         110
# 4           Uimb   2p     front        1  107.62 -0.0981  0.2943         110
# ...          ...  ...       ...      ...     ...     ...     ...         ...
# 58027       Nimb   2p      rear        2   90.00  0.0000  0.0981          90
# 58028       Nimb   2p      rear        2   89.93  0.0000  0.2943          90
# 58029       Nimb   2p      rear        2   89.87  0.0000  0.2943          90
# 58030       Nimb   2p      rear        2   89.87  0.0000  0.2943          90
# 58031       Nimb   2p      rear        2   89.81  0.0000  0.1962          90
#
#        ambiantTemperature
# 0                 24.1875
# 1                 24.1875
# 2                 24.1835
# 3                 24.1835
# 4                 24.1796
# ...                   ...
# 58027             22.1106
# 58028             22.1106
# 58029             22.1106
# 58030             22.1106
# 58031             22.1106
#
# [58032 rows x 9 columns]

# %%
for i in range(0, df.shape[1]):
    plt.hist(df[:][df.columns[i]])
    print(df[:][df.columns[i]].value_counts())
    plt.show()
# Out:
# Nimb    29116
# Imb     18675
# Uimb    10241
# Name: Imbibition, dtype: int64
# 2p    54737
# 4p     3295
# Name: Load, dtype: int64
# front    29069
# rear     28963
# Name: FrontRear, dtype: int64
# 1    29040
# 2    28992
# Name: channel, dtype: int64
# 31.25     4994
# 31.31     3067
# 50.62     2883
# 70.31     2435
# 50.68     1980
#           ...
# 95.00        3
# 98.68        3
# 112.37       2
# 113.81       2
# 111.12       1
# Name: speed, Length: 414, dtype: int64
#  0.0000    25378
# -0.0981    19498
#  0.0981    10157
# -0.1962     2265
# -0.2943      323
#  0.1962      140
#  0.2943       91
# -0.3924       82
# -0.4905       60
#  0.3924       34
#  0.4905        4
# Name: accelX, dtype: int64
#  0.0981    13115
#  0.1962    12077
#  0.0000     8039
# -0.0981     7026
# -0.1962     6935
#  0.2943     5738
# -0.2943     3337
# -0.3924      770
#  0.3924      556
# -0.4905      136
#  0.4905      124
# -0.5886       66
# -0.8829       27
#  0.5886       26
# -0.9810       20
# -0.7848       15
# -0.6867       14
#  0.6867       11
# Name: accelY, dtype: int64
# 30     17169
# 50     14178
# 70      9181
# 90      9083
# 110     8421
# Name: speedClass, dtype: int64
# 0.00000     22990
# 23.69230      664
# 22.89430      306
# 22.34140      280
# 23.00420      274
#             ...
# 9.53316         2
# 5.56632         2
# 11.59620        2
# 5.56936         2
# 8.62339         1
# Name: ambiantTemperature, Length: 2348, dtype: int64

# %%
Liste_supp = ['Load']
Liste_gard = ['Imbibition', 'FrontRear', 'channel', 'speedClass']
Liste_modi = ['speed', 'accelX', 'accelY', 'ambiantTemperature']

# %%
DF = DF.drop(Liste_supp, axis=1)
print(DF.shape)
# Out:
# (58032, 135)

# %%
Liste_quanti = ['speed', 'accelX', 'accelY', 'ambiantTemperature']
Liste_quali = ['Imbibition', 'FrontRear', 'channel', 'speedClass', 'weatherCheck','textureCheck', 'TireWear']

# %%
def rapport_corr(cible,data): #fonction qui calcule le rapport de corrélation
    #cible : 1 variable qualitative
    #data : un DataFrame qui contient des variables quantitatives
    #fournit un graphique représentant les corrélations triées de facon décroissante, l'affiche de ces valeurs et un vecteurs qui les contient
    
    #moyenne par variable
    m=data.mean()
    
    #SCT : variabilité totale = nbre d'ind*variance
    SCT=data.shape[0]*data.var(ddof=0)
    
    #Calcul du SCE
    #DataFrame conditionnellement aux groupes
    Xb=data.groupby(cible)
    #effectifs conditionnels
    nk=Xb.size()
    #moyennes conditionnelles dans chaque groupe
    mk=Xb.mean()
    #pour chaque groupe écart à la moyenne par variable
    EMk=(mk-m)**2
    #pondéré par les effectifs du groupe
    EM=EMk.multiply(nk,axis=0)
    #somme des valeurs=>BSS
    SCE=np.sum(EM,axis=0)
    
    #Calcul du rapport de corrélation
    R2=SCE/SCT
    
    #rendus
    R2trie=R2.sort_values(ascending=False)
    print(R2trie)
    print(R2trie.index)
    plt.bar(range(1,R2trie.shape[0]+1),height=R2trie)
    plt.show()
    return R2trie

# %%
#On commence par les quanli par rapports aux quanti
ListeCouple=[]#liste des couples de forte corrélation
for i in Liste_quali:
    print("Corrélation de ",i)
    rapport=rapport_corr(DF[:][i],DF[:][Liste_quanti])
    if rapport[0]>0.75:# correlation > 0.75
        ListeCouple.append([i,rapport.index[0]])
# Out:
# Corrélation de  Imbibition
# accelX                0.076865
# speed                 0.020148
# ambiantTemperature    0.005811
# accelY                0.001280
# dtype: float64
# Index(['accelX', 'speed', 'ambiantTemperature', 'accelY'], dtype='object')
# Corrélation de  FrontRear
# speed                 3.596131e-05
# ambiantTemperature    2.957048e-06
# accelX                1.549076e-06
# accelY                2.662255e-08
# dtype: float64
# Index(['speed', 'ambiantTemperature', 'accelX', 'accelY'], dtype='object')
# Corrélation de  channel
# speed                 9.944958e-07
# accelX                6.714729e-07
# accelY                1.472400e-07
# ambiantTemperature    7.540180e-08
# dtype: float64
# Index(['speed', 'accelX', 'accelY', 'ambiantTemperature'], dtype='object')
# Corrélation de  speedClass
# speed                 0.999187
# accelY                0.430749
# accelX                0.061609
# ambiantTemperature    0.011640
# dtype: float64
# Index(['speed', 'accelY', 'accelX', 'ambiantTemperature'], dtype='object')
# Corrélation de  weatherCheck
# ambiantTemperature    0.182674
# accelX                0.034434
# speed                 0.011946
# accelY                0.000308
# dtype: float64
# Index(['ambiantTemperature', 'accelX', 'speed', 'accelY'], dtype='object')
# Corrélation de  textureCheck
# speed                 0.016210
# ambiantTemperature    0.015594
# accelY                0.015490
# accelX                0.007116
# dtype: float64
# Index(['speed', 'ambiantTemperature', 'accelY', 'accelX'], dtype='object')
# Corrélation de  TireWear
# accelX                0.152427
# ambiantTemperature    0.076670
# accelY                0.003352
# speed                 0.002947
# dtype: float64
# Index(['accelX', 'ambiantTemperature', 'accelY', 'speed'], dtype='object')

# %%
#'speed' et 'speedClass' sont fortement corrélés 0.99 de correlation
print(ListeCouple)
# Out:
# [['speedClass', 'speed']]

# %%
#X : un dataframe qui ne contient que des variables quantitatives
X=DF[:][Liste_quanti]
matcor=X.corr() 
#nbre de variables à traiter
nbrevarexp=X.shape[1]
#nom des variables
listevarexp=X.columns
#préparation du dataframe qui contiendra : les coefficients de corrélation, la valeur absolue de ce coef et les noms des deux variables considérées
corrligne=pd.DataFrame(columns=["corr","abscorr","nom1","nom2"],index=range(0,nbrevarexp*(nbrevarexp-1)//2))
#calcul de tous les coefficients nécessaires (matrice symétrique)
val=0
for i in range(0,nbrevarexp-1):
    for j in range(i+1,nbrevarexp):
        corrligne["corr"][val]=matcor[listevarexp[i]][listevarexp[j]]
        corrligne["abscorr"][val]=abs(matcor[listevarexp[i]][listevarexp[j]])
        corrligne["nom1"][val]=listevarexp[i]
        corrligne["nom2"][val]=listevarexp[j]
        val+=1
#trie des valeurs de facon décroissante
corr=corrligne.sort_values(by="abscorr",ascending=False)
print(corr.head(15))
# Out:
#        corr   abscorr    nom1                nom2
# 3 -0.294997  0.294997  accelX              accelY
# 1 -0.209894  0.209894   speed              accelY
# 2 -0.075063  0.075063   speed  ambiantTemperature
# 5  0.074097  0.074097  accelY  ambiantTemperature
# 4  0.066687  0.066687  accelX  ambiantTemperature
# 0  0.019615  0.019615   speed              accelX

# %%
#Meme principe que précédemment mais entre les quanti
i=0
while corr["abscorr"][corr.index[i]]>0.75:
    ListeCouple.append([corr["nom1"][corr.index[i]],corr["nom2"][corr.index[i]]])
    i+=1
print(ListeCouple)
# Out:
# [['speedClass', 'speed']]

# %%
import scipy.stats as ss
def cramers_v(x, y):#fonction qui calcule le V de cramer entre 2 variables qualitatives
    #x,y : vecteurs contenant une var quali
    confusion_matrix = pd.crosstab(x,y)
    #calcul du chi² à partir de la table de contingence
    chi2 = ss.chi2_contingency(confusion_matrix)[0]
    #nbre total d'individus
    n = confusion_matrix.sum().sum()
    phi2 = chi2/n
    #nbre de modalités de chaque variable
    r,k = confusion_matrix.shape
    phi2corr = max(0, phi2-((k-1)*(r-1))/(n-1))
    rcorr = r-((r-1)**2)/(n-1)
    kcorr = k-((k-1)**2)/(n-1)
    return np.sqrt(phi2corr/min((kcorr-1),(rcorr-1)))

# %%
# quali-quali
for i in range (0, len(Liste_quali)) :
  for j in range (i+1, len(Liste_quali)):
    print(Liste_quali[i], Liste_quali[j], cramers_v(DF[:][Liste_quali[i]], DF[:][Liste_quali[j]]))
    if(cramers_v(DF[:][Liste_quali[i]], DF[:][Liste_quali[j]])>0.75):
        ListeCouple.append([Liste_quali[i],Liste_quali[j]])

#'Imbibition' et 'weatherCheck' ont un taux de corrélation de 0.63 
#On garde quand même 'Imbibition'
# Out:
# Imbibition FrontRear 0.0
# Imbibition channel 0.0
# Imbibition speedClass 0.14969738901498927
# Imbibition weatherCheck 0.6357709675027114
# Imbibition textureCheck 0.30245322648946205
# Imbibition TireWear 0.11574107305062177
# FrontRear channel 0.0
# FrontRear speedClass 0.0
# FrontRear weatherCheck 0.0
# FrontRear textureCheck 0.0
# FrontRear TireWear 0.0
# channel speedClass 0.0
# channel weatherCheck 0.0
# channel textureCheck 0.0
# channel TireWear 0.0
# speedClass weatherCheck 0.08273444538163731
# speedClass textureCheck 0.10111664343665275
# speedClass TireWear 0.05712801612683234
# weatherCheck textureCheck 0.3591235047915835
# weatherCheck TireWear 0.0815330290669244
# textureCheck TireWear 0.04593707228338091

# %%
#On supprime une des variables de chaque couple
for i in range (len(ListeCouple)):
    print(ListeCouple[i])
# Out:
# ['speedClass', 'speed']

# %%
#On supprime 'speed' car il est correlé à 99% avec 'speedClass' et que 'speedClass' fait partie des colonnes a ne pas modifier 
#tandis que 'spped' fait partie de celle à modifier

DF = DF.drop('speed', axis=1)

# %%
#On change donc les listes avec les nouvelles modifications
Liste_supp = ['Load', 'speed']
Liste_gard = ['Imbibition', 'FrontRear', 'channel', 'speedClass']
Liste_modi = ['accelX', 'accelY', 'ambiantTemperature']

# %%
from sklearn.datasets import load_iris
from sklearn.preprocessing import StandardScaler, robust_scale, MinMaxScaler
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import DecisionTreeRegressor
from sklearn.tree import export_graphviz, plot_tree
from collections import Counter
from scipy.cluster.hierarchy import dendrogram, linkage,fcluster

# %%
#centrage et réduction
VariableModifSansCorr = ['accelX', 'accelY']
centrage=StandardScaler()
centrage.fit(DF[VariableModifSansCorr])
donnéeCR=centrage.transform(DF[VariableModifSansCorr])

# %%
#'accelX'
#Arbre de décision
varapred = ['textureCheck', 'weatherCheck', 'TireWear']
arbre_cla=DecisionTreeClassifier(max_depth=3,min_samples_leaf=5000)
arbre_cla.fit(DF['accelX'].to_numpy().reshape(DF['accelX'].to_numpy().shape[0],1),DF[varapred])
plot_tree(arbre_cla, filled=True,feature_names="accelX")
plt.show()

# %%
#'accelY'
#Arbre de décision
varapred = ['textureCheck', 'weatherCheck', 'TireWear']
arbre_cla=DecisionTreeClassifier(max_depth=2,min_samples_leaf=5000)
arbre_cla.fit(DF['accelY'].to_numpy().reshape(DF['accelY'].to_numpy().shape[0],1),DF[varapred])
plot_tree(arbre_cla, filled=True,feature_names="accelY")
plt.show()

# %%
#'ambiantTemperature'
#Arbre de décision
varapred = ['textureCheck', 'weatherCheck', 'TireWear']
arbre_cla=DecisionTreeClassifier(max_depth=2,min_samples_leaf=5000)
arbre_cla.fit(DF['ambiantTemperature'].to_numpy().reshape(DF['ambiantTemperature'].to_numpy().shape[0],1),DF[varapred])
plot_tree(arbre_cla, filled=True,feature_names="ambiantTemperature")
plt.show()
